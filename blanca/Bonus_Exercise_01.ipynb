# %% [markdown]
# This is the execution notebook for Bonus exercise 01.

# %% [markdown]
# For assignment 1.1.
# Instructions:
# Solution:
# Insights:

# %%
# %run assignment_1.1.py
# Out:
# Python implementation
# Mean:     1.647059
# Variance: 0.148897
#
# NumPy implementation with ddof=0
# Mean:     1.647059
# Variance: 0.140138
#
# NumPy implementation with ddof=1
# Mean:     1.647059
# Variance: 0.148897
#
# Comparison
# The means agree because both implementations compute the same sample mean.
# The Python variance agrees with NumPy only for ddof=1, because both then divide by N - 1.
# NumPy's default ddof=0 divides by N and therefore computes the biased population variance.

# %% [markdown]
# Interpretation of results:

# %% [markdown]
# For assignment 1.2.
# Instructions:
# Solution:
# Insight

# %%
# %run assignment_1.2.py
# Out:
# N = 10
# Estimated mean:
# [-0.5811197   0.78748464]
# Estimated covariance:
# [[ 1.66874103 -0.16511617]
#  [-0.16511617  0.47088377]]
#
# N = 100
# Estimated mean:
# [-0.36547733  1.06675853]
# Estimated covariance:
# [[1.75958382 0.23050613]
#  [0.23050613 0.65034275]]
#
# N = 1000
# Estimated mean:
# [-0.28950557  1.10056329]
# Estimated covariance:
# [[2.01786292 0.32103036]
#  [0.32103036 0.96747969]]
#
# N = 10000
# Estimated mean:
# [-0.40091235  1.11160838]
# Estimated covariance:
# [[1.98791843 0.36409937]
#  [0.36409937 1.00912979]]

# %% [markdown]
# Interpretation of results

# %%
# %run assignment_2.py
# Out:
# Assignment 2.1: direct sampling on [0, 1]
# Exact integral: 0.45969769
# N =    10 | estimate = 0.47581552 | error = 0.01611782 | RMSE = 0.08636807
# N =   100 | estimate = 0.43302626 | error = 0.02667143 | RMSE = 0.02570408
# N =  1000 | estimate = 0.45089187 | error = 0.00880583 | RMSE = 0.00794286
# N = 10000 | estimate = 0.45483267 | error = 0.00486502 | RMSE = 0.00247115
#
# Assignment 2.2: direct sampling on [2, 4]
# Exact integral: 0.23749678
# N =    10 | estimate = 0.15253903 | error = 0.08495776 | RMSE = 0.35731470
# N =   100 | estimate = 0.34015134 | error = 0.10265455 | RMSE = 0.10616370
# N =  1000 | estimate = 0.27111060 | error = 0.03361382 | RMSE = 0.03304667
# N = 10000 | estimate = 0.25874447 | error = 0.02124769 | RMSE = 0.01030407
#
# Assignment 2.2: transformed sampling on [2, 4]
# Exact integral: 0.23749678
# N =    10 | estimate = 0.15253903 | error = 0.08495776 | RMSE = 0.35731470
# N =   100 | estimate = 0.34015134 | error = 0.10265455 | RMSE = 0.10616370
# ...

# %% [markdown]
# Interpretation of results:

# %%
# %run assignment_3.py
# Out:
# Absolute errors for Assignment 3
#
#        N |           MC |        CV h1 |        CV h2 |        CV h3 |    IS β(5,1) |    IS β(.5,.5)
#       10 | 3.874586e-02 | 5.176378e-03 | 5.176378e-03 | 9.066013e-04 | 5.263041e-01 |   2.001313e-02
#      100 | 4.622057e-02 | 3.522729e-03 | 3.522729e-03 | 1.227601e-03 | 2.238685e-01 |   8.320719e-02
#     1000 | 1.479538e-02 | 1.609985e-03 | 1.609985e-03 | 5.721454e-04 | 3.189538e-01 |   3.245717e-02
#    10000 | 1.034948e-02 | 4.998732e-04 | 4.998732e-04 | 1.235839e-04 | 2.106576e-01 |   1.706095e-03

# %%
from utils.sampling import monte_carlo
import chaospy as cp
import numpy as np

estimate, rmse = monte_carlo(
    p=cp.Uniform(0.0, 1.0),
    n_samples=10000,
    f=np.exp,
)

print(estimate)
# Out:
# [1.70793235]

# %%
# %run assignment_4.py
# Out:
# Assignment 4: relative errors for y(10)
#
# Reference mean:     -0.43893703
# Reference variance: 0.00019678
# Deterministic y(10): -0.45273580
#
#             Method |        N |   Mean error | Variance error
#        Monte Carlo |       10 | 1.365765e-03 |   1.452802e-01
#        Monte Carlo |      100 | 3.455862e-03 |   1.035184e-01
#        Monte Carlo |     1000 | 1.206226e-03 |   3.719026e-02
#        Monte Carlo |    10000 | 2.439731e-05 |   9.388866e-03
#  Quasi-Monte Carlo |       10 | 3.555523e-04 |   2.763615e-02
#  Quasi-Monte Carlo |      100 | 2.103761e-04 |   2.984482e-02
#  Quasi-Monte Carlo |     1000 | 6.758388e-05 |   1.592347e-03
#  Quasi-Monte Carlo |    10000 | 6.502156e-05 |   1.184493e-03
